# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
df2 = pd.read_csv('MSFT.csv')
df2
# Out:
#             Date   Open   High    Low  Close     Volume  Name
# 0     2006-01-03  26.25  27.00  26.10  26.84   79974418  MSFT
# 1     2006-01-04  26.77  27.08  26.77  26.97   57975661  MSFT
# 2     2006-01-05  26.96  27.13  26.91  26.99   48247610  MSFT
# 3     2006-01-06  26.89  27.00  26.49  26.91  100969092  MSFT
# 4     2006-01-09  26.93  27.07  26.76  26.86   55627836  MSFT
# 5     2006-01-10  26.65  27.02  26.59  27.00   64924946  MSFT
# 6     2006-01-11  27.01  27.39  26.90  27.29   70123544  MSFT
# 7     2006-01-12  27.25  27.26  26.97  27.14   45994725  MSFT
# 8     2006-01-13  27.03  27.25  27.01  27.19   41449046  MSFT
# 9     2006-01-17  26.90  27.19  26.90  26.99   58574807  MSFT
# 10    2006-01-18  26.74  26.98  26.70  26.83   52495587  MSFT
# 11    2006-01-19  26.87  27.24  26.85  27.02   60382450  MSFT
# 12    2006-01-20  27.01  27.01  26.26  26.41   79228490  MSFT
# 13    2006-01-23  26.41  26.53  26.30  26.35   47971611  MSFT
# ...

# %%
stock = df.append(df2, ignore_index=True)

# %%
plt.xlabel('Opening Date')
plt.ylabel('Price per Stock')
plt.title('Historical Apple Opening Prices')
plt.plot(df.Open)

# Shows Apples opening prices since going public.

# %%
plt.xlabel('Opening Date')
plt.ylabel('Price per Stock')
plt.title('Microsoft vs. Apple Opening Prices')
plt.plot(df.Open)
plt.plot(df2.Open)

# Compares Microsoft and Apples  opening stock prices since they went public.

# %%
fig, ax1 = plt.subplots()
ax1.plot(df.Open, color='black')
ax1.set_xlabel('Opening Date')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Open', color='black')
ax1.tick_params('y', colors='black')

ax2 = ax1.twinx()
ax2.plot(df.Volume, color='gray', alpha= 0.2)
ax2.set_ylabel('Volume', color='black')
ax2.tick_params('y', colors='black')

# Shows trading volume compared to the opening stock price of Apple. From public opening date til end of 2017.

# %%
fig, ax1 = plt.subplots()
ax1.plot(df2.Open, color='black')
ax1.set_xlabel('Opening Date')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Open', color='black')
ax1.tick_params('y', colors='black')

ax2 = ax1.twinx()
ax2.plot(df2.Volume, color='gray', alpha= 0.2)
ax2.set_ylabel('Volume', color='black')
ax2.tick_params('y', colors='black')

# Shows trading volume compared to the opening stock price of Microsoft. From public opening date til end of 2017.
